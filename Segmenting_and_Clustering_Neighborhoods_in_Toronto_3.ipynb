# %% [markdown]
# ## Segmenting and Clustering Neighborhoods in Toronto

# %%
import pandas as pd
import numpy as np
import requests

# %%
# Grab the table on the wikipedia page.
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')[0]

# %%
# When Borough is 'Not assigned', abandon them.
df = df[df.Borough!='Not assigned']

# %%
# When Neighbourhood is 'Not assigned', replace it with Borough.
for i in range(df.shape[0]):
    if df.iloc[i,2]=='Not assigned':
        df.iloc[i,2]=df.iloc[i,1]

# %% [markdown]
# ### Add Latitude and Longitude for each Postcode.

# %%
# Read csv to df_geo.
df_geo = pd.read_csv('Geospatial_Coordinates.csv')
# Rename the column name of df_geo, so that it can merge with df.
df_geo.rename(columns={'Postal Code':'Postcode'},inplace=True)

# %%
# Merge df and df_geo.
neighborhoods = pd.merge(df,df_geo,how='left',on='Postcode')
neighborhoods = neighborhoods.drop(columns='Postcode')

# %%
neighborhoods = neighborhoods[neighborhoods['Borough'].str.contains('Toronto')]
neighborhoods.rename(columns={'Neighbourhood':'Neighborhood'},inplace=True)
neighborhoods.index=[i for i in range(neighborhoods.shape[0])]
toronto_data = neighborhoods
toronto_data.head()
# Out:
#             Borough     Neighborhood   Latitude  Longitude
# 0  Downtown Toronto     Harbourfront  43.654260 -79.360636
# 1  Downtown Toronto      Regent Park  43.654260 -79.360636
# 2  Downtown Toronto          Ryerson  43.657162 -79.378937
# 3  Downtown Toronto  Garden District  43.657162 -79.378937
# 4  Downtown Toronto   St. James Town  43.651494 -79.375418

# %%
# Get the geo of Toronto.
# from geopy.geocoders import Nominatim
# address = 'Toronto'
# geolocator = Nominatim(user_agent="ny_explorer")
# location = geolocator.geocode(address)
# latitude = location.latitude
# longitude = location.longitude
# print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# The geograpical coordinate of Toronto are 43.653963, -79.387207.
latitude = 43.653963
longitude = -79.387207

# %%
CLIENT_ID = 'IOV2GAGHT5QIZDIKYCJIBJTJUWP2QGO1EKICQVTC2NO1IALU' # your Foursquare ID
CLIENT_SECRET = 'ARNCSIMQGAQ0AIVPJTSTR0MWXBTV4MDHIHNOX0YTMUEYQUAP' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 #Venues count limit

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

toronto_venues = getNearbyVenues(names=toronto_data['Neighborhood'],
                                   latitudes=toronto_data['Latitude'],
                                   longitudes=toronto_data['Longitude']
                                  )
# Out:
# Harbourfront
# Regent Park
# Ryerson
# Garden District
# St. James Town
# The Beaches
# Berczy Park
# Central Bay Street
# Christie
# Adelaide
# King
# Richmond
# Dovercourt Village
# Dufferin
# Harbourfront East
# Toronto Islands
# Union Station
# Little Portugal
# Trinity
# The Danforth West
# Riverdale
# Design Exchange
# Toronto Dominion Centre
# Brockton
# Exhibition Place
# Parkdale Village
# The Beaches West
# India Bazaar
# Commerce Court
# Victoria Hotel
# Studio District
# Lawrence Park
# Roselawn
# Davisville North
# Forest Hill North
# Forest Hill West
# High Park
# The Junction South
# North Toronto West
# The Annex
# North Midtown
# Yorkville
# Parkdale
# Roncesvalles
# Davisville
# Harbord
# University of Toronto
# Runnymede
# Swansea
# Moore Park
# Summerhill East
# Chinatown
# Grange Park
# Kensington Market
# Deer Park
# Forest Hill SE
# Rathnelly
# South Hill
# Summerhill West
# CN Tower
# Bathurst Quay
# Island airport
# Harbourfront West
# King and Spadina
# Railway Lands
# South Niagara
# Rosedale
# Stn A PO Boxes 25 The Esplanade
# Cabbagetown
# St. James Town
# First Canadian Place
# Underground city
# Church and Wellesley
# Business Reply Mail Processing Centre 969 Eastern

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                           Adelaide           Coffee Shop
# 1                                      Bathurst Quay        Airport Lounge
# 2                                        Berczy Park           Coffee Shop
# 3                                           Brockton           Coffee Shop
# 4  Business Reply Mail Processing Centre 969 Eastern    Light Rail Station
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                  Café       Thai Restaurant                   Bar
# 1       Airport Service      Airport Terminal              Boutique
# 2          Cocktail Bar                  Café        Farmers Market
# 3                  Café        Breakfast Spot  Gym / Fitness Center
# 4  Gym / Fitness Center                Garden           Pizza Place
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0              Steakhouse                Bakery          Burger Joint
# 1        Sculpture Garden       Harbor / Marina               Airport
# 2      Seafood Restaurant           Cheese Shop            Steakhouse
# 3  Furniture / Home Store     Convenience Store          Climbing Gym
# 4        Recording Studio            Restaurant               Butcher
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0                 Hotel      Sushi Restaurant    American Restaurant
# 1    Airport Food Court          Airport Gate                  Plane
# 2                Bakery    Italian Restaurant             Restaurant
# 3            Restaurant  Caribbean Restaurant          Burrito Place
# 4         Burrito Place            Skate Park                Brewery

# %%
from sklearn.cluster import KMeans

# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 2, 0, 0, 0, 2, 0, 0, 0, 0], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = toronto_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head() # check the last columns!
# Out:
#             Borough     Neighborhood   Latitude  Longitude  Cluster Labels  \
# 0  Downtown Toronto     Harbourfront  43.654260 -79.360636               0
# 1  Downtown Toronto      Regent Park  43.654260 -79.360636               0
# 2  Downtown Toronto          Ryerson  43.657162 -79.378937               0
# 3  Downtown Toronto  Garden District  43.657162 -79.378937               0
# 4  Downtown Toronto   St. James Town  43.651494 -79.375418               0
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0           Coffee Shop                  Café                Bakery
# 1           Coffee Shop                  Café                Bakery
# 2           Coffee Shop        Clothing Store        Cosmetics Shop
# 3           Coffee Shop        Clothing Store        Cosmetics Shop
# 4           Coffee Shop            Restaurant                  Café
#
#   4th Most Common Venue      5th Most Common Venue 6th Most Common Venue  \
# 0                   Pub                       Park    Mexican Restaurant
# 1                   Pub                       Park    Mexican Restaurant
# 2                  Café  Middle Eastern Restaurant            Restaurant
# 3                  Café  Middle Eastern Restaurant            Restaurant
# 4                Bakery             Breakfast Spot                 Hotel
#
#   7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0        Breakfast Spot               Theater    Italian Restaurant
# 1        Breakfast Spot               Theater    Italian Restaurant
# 2       Thai Restaurant           Pizza Place    Italian Restaurant
# 3       Thai Restaurant           Pizza Place    Italian Restaurant
# 4           Pizza Place             Gastropub    Italian Restaurant
#
#   10th Most Common Venue
# 0         Chocolate Shop
# 1         Chocolate Shop
# 2    Japanese Restaurant
# 3    Japanese Restaurant
# 4                   Park

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors
import folium

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                                          Neighborhood 1st Most Common Venue  \
# 0                                        Harbourfront           Coffee Shop
# 1                                         Regent Park           Coffee Shop
# 2                                             Ryerson           Coffee Shop
# 3                                     Garden District           Coffee Shop
# 4                                      St. James Town           Coffee Shop
# 5                                         The Beaches           Coffee Shop
# 6                                         Berczy Park           Coffee Shop
# 7                                  Central Bay Street           Coffee Shop
# 8                                            Christie         Grocery Store
# 9                                            Adelaide           Coffee Shop
# 10                                               King           Coffee Shop
# 11                                           Richmond           Coffee Shop
# 12                                 Dovercourt Village        Discount Store
# 13                                           Dufferin        Discount Store
# 14                                  Harbourfront East           Coffee Shop
# 15                                    Toronto Islands           Coffee Shop
# 16                                      Union Station           Coffee Shop
# 17                                    Little Portugal                   Bar
# 18                                            Trinity                   Bar
# 19                                  The Danforth West      Greek Restaurant
# 20                                          Riverdale      Greek Restaurant
# 21                                    Design Exchange           Coffee Shop
# 22                            Toronto Dominion Centre           Coffee Shop
# 23                                           Brockton           Coffee Shop
# 24                                   Exhibition Place           Coffee Shop
# 25                                   Parkdale Village           Coffee Shop
# 26                                   The Beaches West        Sandwich Place
# 27                                       India Bazaar        Sandwich Place
# 28                                     Commerce Court           Coffee Shop
# 29                                     Victoria Hotel           Coffee Shop
# ..                                                ...                   ...
# 31                                      Lawrence Park                  Park
# 33                                   Davisville North        Sandwich Place
# 36                                          High Park                  Café
# 37                                 The Junction South                  Café
# 38                                 North Toronto West   Sporting Goods Shop
# 39                                          The Annex           Coffee Shop
# 40                                      North Midtown           Coffee Shop
# 41                                          Yorkville           Coffee Shop
# 42                                           Parkdale        Breakfast Spot
# 43                                       Roncesvalles        Breakfast Spot
# 44                                         Davisville           Pizza Place
# 45                                            Harbord                  Café
# 46                              University of Toronto                  Café
# 47                                          Runnymede           Pizza Place
# 48                                            Swansea           Pizza Place
# 51                                          Chinatown                  Café
# 52                                        Grange Park                  Café
# 53                                  Kensington Market                  Café
# 54                                          Deer Park           Coffee Shop
# 55                                     Forest Hill SE           Coffee Shop
# 56                                          Rathnelly           Coffee Shop
# 57                                         South Hill           Coffee Shop
# 58                                    Summerhill West           Coffee Shop
# 67                    Stn A PO Boxes 25 The Esplanade           Coffee Shop
# 68                                        Cabbagetown           Coffee Shop
# 69                                     St. James Town           Coffee Shop
# 70                               First Canadian Place           Coffee Shop
# 71                                   Underground city           Coffee Shop
# 72                               Church and Wellesley           Coffee Shop
# 73  Business Reply Mail Processing Centre 969 Eastern    Light Rail Station
#
#     2nd Most Common Venue 3rd Most Common Venue  \
# 0                    Café                Bakery
# 1                    Café                Bakery
# 2          Clothing Store        Cosmetics Shop
# 3          Clothing Store        Cosmetics Shop
# 4              Restaurant                  Café
# 5       Health Food Store                   Pub
# 6            Cocktail Bar                  Café
# 7                    Café    Italian Restaurant
# 8                    Café                  Park
# 9                    Café       Thai Restaurant
# 10                   Café       Thai Restaurant
# 11                   Café       Thai Restaurant
# 12               Pharmacy           Supermarket
# 13               Pharmacy           Supermarket
# 14                  Hotel              Aquarium
# 15                  Hotel              Aquarium
# 16                  Hotel              Aquarium
# 17            Coffee Shop      Asian Restaurant
# 18            Coffee Shop      Asian Restaurant
# 19            Coffee Shop        Ice Cream Shop
# 20            Coffee Shop        Ice Cream Shop
# 21                   Café                 Hotel
# 22                   Café                 Hotel
# 23                   Café        Breakfast Spot
# 24                   Café        Breakfast Spot
# 25                   Café        Breakfast Spot
# 26            Pizza Place                  Park
# 27            Pizza Place                  Park
# 28                   Café                 Hotel
# 29                   Café                 Hotel
# ..                    ...                   ...
# 31            Swim School              Bus Line
# 33         Breakfast Spot                   Gym
# 36     Mexican Restaurant   Fried Chicken Joint
# 37     Mexican Restaurant   Fried Chicken Joint
# 38            Coffee Shop        Clothing Store
# 39         Sandwich Place                  Café
# 40         Sandwich Place                  Café
# 41         Sandwich Place                  Café
# 42              Gift Shop          Dessert Shop
# 43              Gift Shop          Dessert Shop
# 44         Sandwich Place          Dessert Shop
# 45                 Bakery                   Bar
# 46                 Bakery                   Bar
# 47                   Café           Coffee Shop
# 48                   Café           Coffee Shop
# 51  Vietnamese Restaurant                   Bar
# 52  Vietnamese Restaurant                   Bar
# 53  Vietnamese Restaurant                   Bar
# 54                    Pub            Bagel Shop
# 55                    Pub            Bagel Shop
# 56                    Pub            Bagel Shop
# 57                    Pub            Bagel Shop
# 58                    Pub            Bagel Shop
# 67             Restaurant                  Café
# 68             Restaurant           Pizza Place
# 69             Restaurant                  Café
# 70                   Café                 Hotel
# 71                   Café                 Hotel
# 72    Japanese Restaurant               Gay Bar
# 73   Gym / Fitness Center                Garden
#
#             4th Most Common Venue      5th Most Common Venue  \
# 0                             Pub                       Park
# 1                             Pub                       Park
# 2                            Café  Middle Eastern Restaurant
# 3                            Café  Middle Eastern Restaurant
# 4                          Bakery             Breakfast Spot
# 5                           Diner             Farmers Market
# 6                  Farmers Market         Seafood Restaurant
# 7                    Burger Joint                        Bar
# 8              Athletics & Sports                  Nightclub
# 9                             Bar                 Steakhouse
# 10                            Bar                 Steakhouse
# 11                            Bar                 Steakhouse
# 12                         Bakery                Music Venue
# 13                         Bakery                Music Venue
# 14                           Café         Italian Restaurant
# 15                           Café         Italian Restaurant
# 16                           Café         Italian Restaurant
# 17                    Men's Store                 Restaurant
# 18                    Men's Store                 Restaurant
# 19             Italian Restaurant                  Bookstore
# 20             Italian Restaurant                  Bookstore
# 21            American Restaurant                  Gastropub
# 22            American Restaurant                  Gastropub
# 23           Gym / Fitness Center     Furniture / Home Store
# 24           Gym / Fitness Center     Furniture / Home Store
# 25           Gym / Fitness Center     Furniture / Home Store
# 26                        Brewery               Burger Joint
# 27                        Brewery               Burger Joint
# 28                     Restaurant        American Restaurant
# 29                     Restaurant        American Restaurant
# ..                            ...                        ...
# 31                  Women's Store                   Dive Bar
# 33                  Grocery Store                       Park
# 36                Thai Restaurant                     Bakery
# 37                Thai Restaurant                     Bakery
# 38                    Yoga Studio         Italian Restaurant
# 39                    Pizza Place                       Park
# 40                    Pizza Place                       Park
# 41                    Pizza Place                       Park
# 42                  Movie Theater                    Dog Run
# 43                  Movie Theater                    Dog Run
# 44             Italian Restaurant                       Café
# 45            Japanese Restaurant                  Bookstore
# 46            Japanese Restaurant                  Bookstore
# 47               Sushi Restaurant         Italian Restaurant
# 48               Sushi Restaurant         Italian Restaurant
# 51  Vegetarian / Vegan Restaurant         Chinese Restaurant
# 52  Vegetarian / Vegan Restaurant         Chinese Restaurant
# 53  Vegetarian / Vegan Restaurant         Chinese Restaurant
# 54              Convenience Store                Pizza Place
# 55              Convenience Store                Pizza Place
# 56              Convenience Store                Pizza Place
# 57              Convenience Store                Pizza Place
# 58              Convenience Store                Pizza Place
# 67                          Hotel         Seafood Restaurant
# 68             Italian Restaurant                     Bakery
# 69                         Bakery             Breakfast Spot
# 70                     Steakhouse                        Gym
# 71                     Steakhouse                        Gym
# 72                     Restaurant               Burger Joint
# 73                    Pizza Place           Recording Studio
#
#     6th Most Common Venue      7th Most Common Venue  \
# 0      Mexican Restaurant             Breakfast Spot
# 1      Mexican Restaurant             Breakfast Spot
# 2              Restaurant            Thai Restaurant
# 3              Restaurant            Thai Restaurant
# 4                   Hotel                Pizza Place
# 5      Falafel Restaurant                Event Space
# 6             Cheese Shop                 Steakhouse
# 7         Bubble Tea Shop                Salad Place
# 8      Italian Restaurant                      Diner
# 9                  Bakery               Burger Joint
# 10                 Bakery               Burger Joint
# 11                 Bakery               Burger Joint
# 12           Liquor Store                    Brewery
# 13           Liquor Store                    Brewery
# 14            Pizza Place                    Brewery
# 15            Pizza Place                    Brewery
# 16            Pizza Place                    Brewery
# 17                   Café                     Bakery
# 18                   Café                     Bakery
# 19         Cosmetics Shop                    Brewery
# 20         Cosmetics Shop                    Brewery
# 21     Italian Restaurant                 Restaurant
# 22     Italian Restaurant                 Restaurant
# 23      Convenience Store               Climbing Gym
# 24      Convenience Store               Climbing Gym
# 25      Convenience Store               Climbing Gym
# 26          Burrito Place                        Pub
# 27          Burrito Place                        Pub
# 28          Deli / Bodega                 Steakhouse
# 29          Deli / Bodega                 Steakhouse
# ..                    ...                        ...
# 31         Farmers Market         Falafel Restaurant
# 33                  Hotel           Asian Restaurant
# 36     Italian Restaurant  Cajun / Creole Restaurant
# 37     Italian Restaurant  Cajun / Creole Restaurant
# 38   Fast Food Restaurant         Mexican Restaurant
# 39    American Restaurant          Jewish Restaurant
# 40    American Restaurant          Jewish Restaurant
# 41    American Restaurant          Jewish Restaurant
# 42                    Bar         Italian Restaurant
# 43                    Bar         Italian Restaurant
# 44            Coffee Shop           Sushi Restaurant
# 45             Restaurant                        Pub
# 46             Restaurant                        Pub
# 47               Tea Room               Dessert Shop
# 48               Tea Room               Dessert Shop
# 51                 Bakery                Coffee Shop
# 52                 Bakery                Coffee Shop
# 53                 Bakery                Coffee Shop
# 54  Vietnamese Restaurant         Light Rail Station
# 55  Vietnamese Restaurant         Light Rail Station
# 56  Vietnamese Restaurant         Light Rail Station
# 57  Vietnamese Restaurant         Light Rail Station
# 58  Vietnamese Restaurant         Light Rail Station
# 67     Italian Restaurant       Fast Food Restaurant
# 68                   Café                        Pub
# 69                  Hotel                Pizza Place
# 70    American Restaurant                     Bakery
# 71    American Restaurant                     Bakery
# 72       Sushi Restaurant               Dance Studio
# 73             Restaurant                    Butcher
#
#         8th Most Common Venue        9th Most Common Venue  \
# 0                     Theater           Italian Restaurant
# 1                     Theater           Italian Restaurant
# 2                 Pizza Place           Italian Restaurant
# 3                 Pizza Place           Italian Restaurant
# 4                   Gastropub           Italian Restaurant
# 5        Ethiopian Restaurant            Electronics Store
# 6                      Bakery           Italian Restaurant
# 7            Sushi Restaurant           Chinese Restaurant
# 8                  Restaurant                   Baby Store
# 9                       Hotel             Sushi Restaurant
# 10                      Hotel             Sushi Restaurant
# 11                      Hotel             Sushi Restaurant
# 12  Middle Eastern Restaurant                         Café
# 13  Middle Eastern Restaurant                         Café
# 14                 Restaurant               Scenic Lookout
# 15                 Restaurant               Scenic Lookout
# 16                 Restaurant               Scenic Lookout
# 17                Pizza Place                 Cocktail Bar
# 18                Pizza Place                 Cocktail Bar
# 19            Bubble Tea Shop                   Restaurant
# 20            Bubble Tea Shop                   Restaurant
# 21         Seafood Restaurant                Deli / Bodega
# 22         Seafood Restaurant                Deli / Bodega
# 23                 Restaurant         Caribbean Restaurant
# 24                 Restaurant         Caribbean Restaurant
# 25                 Restaurant         Caribbean Restaurant
# 26                  Pet Store                Movie Theater
# 27                  Pet Store                Movie Theater
# 28                     Bakery                          Gym
# 29                     Bakery                          Gym
# ..                        ...                          ...
# 31                Event Space         Ethiopian Restaurant
# 33               Burger Joint            Food & Drink Shop
# 36     Furniture / Home Store                        Diner
# 37     Furniture / Home Store                        Diner
# 38                      Diner                 Dessert Shop
# 39                  BBQ Joint            Indian Restaurant
# 40                  BBQ Joint            Indian Restaurant
# 41                  BBQ Joint            Indian Restaurant
# 42                 Restaurant  Eastern European Restaurant
# 43                 Restaurant  Eastern European Restaurant
# 44           Greek Restaurant           Seafood Restaurant
# 45                   Beer Bar                   Beer Store
# 46                   Beer Bar                   Beer Store
# 47              Smoothie Shop                    Bookstore
# 48              Smoothie Shop                    Bookstore
# 51         Mexican Restaurant         Caribbean Restaurant
# 52         Mexican Restaurant         Caribbean Restaurant
# 53         Mexican Restaurant         Caribbean Restaurant
# 54                Supermarket          Fried Chicken Joint
# 55                Supermarket          Fried Chicken Joint
# 56                Supermarket          Fried Chicken Joint
# 57                Supermarket          Fried Chicken Joint
# 58                Supermarket          Fried Chicken Joint
# 67               Cocktail Bar                     Creperie
# 68                Yoga Studio               Breakfast Spot
# 69                  Gastropub           Italian Restaurant
# 70                        Bar                Deli / Bodega
# 71                        Bar                Deli / Bodega
# 72       Fast Food Restaurant                  Men's Store
# 73              Burrito Place                   Skate Park
#
#          10th Most Common Venue
# 0                Chocolate Shop
# 1                Chocolate Shop
# 2           Japanese Restaurant
# 3           Japanese Restaurant
# 4                          Park
# 5   Eastern European Restaurant
# 6                    Restaurant
# 7               Thai Restaurant
# 8                   Coffee Shop
# 9           American Restaurant
# 10          American Restaurant
# 11          American Restaurant
# 12                          Bar
# 13                          Bar
# 14               History Museum
# 15               History Museum
# 16               History Museum
# 17                     Boutique
# 18                     Boutique
# 19         Caribbean Restaurant
# 20         Caribbean Restaurant
# 21                 Concert Hall
# 22                 Concert Hall
# 23                Burrito Place
# 24                Burrito Place
# 25                Burrito Place
# 26             Sushi Restaurant
# 27             Sushi Restaurant
# 28           Seafood Restaurant
# 29           Seafood Restaurant
# ..                          ...
# 31            Electronics Store
# 33          Dumpling Restaurant
# 36                    Speakeasy
# 37                    Speakeasy
# 38                         Park
# 39                          Pub
# 40                          Pub
# 41                          Pub
# 42                         Bank
# 43                         Bank
# 44                 Burger Joint
# 45               Sandwich Place
# 46               Sandwich Place
# 47               Sandwich Place
# 48               Sandwich Place
# 51            Hotpot Restaurant
# 52            Hotpot Restaurant
# 53            Hotpot Restaurant
# 54               Medical Center
# 55               Medical Center
# 56               Medical Center
# 57               Medical Center
# 58               Medical Center
# 67                     Beer Bar
# 68               Sandwich Place
# 69                         Park
# 70           Seafood Restaurant
# 71           Seafood Restaurant
# 72              Bubble Tea Shop
# 73                      Brewery
#
# [61 rows x 11 columns]

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#          Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 34  Forest Hill North                 Trail         Jewelry Store
# 35   Forest Hill West                 Trail         Jewelry Store
# 66           Rosedale                  Park            Playground
#
#    3rd Most Common Venue 4th Most Common Venue        5th Most Common Venue  \
# 34                  Park      Sushi Restaurant  Eastern European Restaurant
# 35                  Park      Sushi Restaurant  Eastern European Restaurant
# 66                 Trail                 Diner               Farmers Market
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 34               Dog Run      Doner Restaurant            Donut Shop
# 35               Dog Run      Doner Restaurant            Donut Shop
# 66    Falafel Restaurant           Event Space  Ethiopian Restaurant
#
#    9th Most Common Venue       10th Most Common Venue
# 34   Dumpling Restaurant                Women's Store
# 35   Dumpling Restaurant                Women's Store
# 66     Electronics Store  Eastern European Restaurant

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#          Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 59           CN Tower        Airport Lounge       Airport Service
# 60      Bathurst Quay        Airport Lounge       Airport Service
# 61     Island airport        Airport Lounge       Airport Service
# 62  Harbourfront West        Airport Lounge       Airport Service
# 63   King and Spadina        Airport Lounge       Airport Service
# 64      Railway Lands        Airport Lounge       Airport Service
# 65      South Niagara        Airport Lounge       Airport Service
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 59      Airport Terminal              Boutique      Sculpture Garden
# 60      Airport Terminal              Boutique      Sculpture Garden
# 61      Airport Terminal              Boutique      Sculpture Garden
# 62      Airport Terminal              Boutique      Sculpture Garden
# 63      Airport Terminal              Boutique      Sculpture Garden
# 64      Airport Terminal              Boutique      Sculpture Garden
# 65      Airport Terminal              Boutique      Sculpture Garden
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 59       Harbor / Marina               Airport    Airport Food Court
# 60       Harbor / Marina               Airport    Airport Food Court
# 61       Harbor / Marina               Airport    Airport Food Court
# 62       Harbor / Marina               Airport    Airport Food Court
# 63       Harbor / Marina               Airport    Airport Food Court
# 64       Harbor / Marina               Airport    Airport Food Court
# 65       Harbor / Marina               Airport    Airport Food Court
#
#    9th Most Common Venue 10th Most Common Venue
# 59          Airport Gate                  Plane
# 60          Airport Gate                  Plane
# 61          Airport Gate                  Plane
# 62          Airport Gate                  Plane
# 63          Airport Gate                  Plane
# 64          Airport Gate                  Plane
# 65          Airport Gate                  Plane

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#        Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 49       Moore Park            Playground                   Gym
# 50  Summerhill East            Playground                   Gym
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 49          Tennis Court            Restaurant      Doner Restaurant
# 50          Tennis Court            Restaurant      Doner Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 49                 Diner        Discount Store              Dive Bar
# 50                 Diner        Discount Store              Dive Bar
#
#    9th Most Common Venue 10th Most Common Venue
# 49               Dog Run             Donut Shop
# 50               Dog Run             Donut Shop

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#    Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 32     Roselawn                Garden                  Pool
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 32         Women's Store        Farmers Market    Falafel Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 32           Event Space  Ethiopian Restaurant     Electronics Store
#
#           9th Most Common Venue 10th Most Common Venue
# 32  Eastern European Restaurant    Dumpling Restaurant
